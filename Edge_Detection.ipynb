# %%
from google.colab import files
import cv2 as cv
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import numpy as np
import tensorflow as tf

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d6ddd3ba-02c2-4b06-a71f-edec22f8f65f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6ddd3ba-02c2-4b06-a71f-edec22f8f65f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Profile picture.jpg to Profile picture.jpg

# %%
img=cv2.imread('Profile picture.jpg')
plt.imshow(img)

# %%
gray_image = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
up_points=(300,400)
gray_image1 = cv2.resize(gray_image, up_points, interpolation = cv2.INTER_LINEAR)
cv2_imshow(gray_image1)
# Out:
# <PIL.Image.Image image mode=L size=300x400 at 0x7F0E83388BD0>

# %%
sobelx = cv2.Sobel(gray_image1,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(gray_image1,cv2.CV_64F,0,1,ksize=5)
laplacian = cv2.Laplacian(gray_image1,cv2.CV_64F)
